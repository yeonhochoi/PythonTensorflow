# %%
#텐서플로를 이용해 이미지를 불러오고 자르기 명령어를 통해 이미지의 일부분만을 추출해보자.

# %%
#matplotlib의 imread 명령어를 이용해 표준 형식(JPG,BMP,TIF)의 컬러 이미지 파일을 불러온다.
import tensorflow as tf
import matplotlib.image as mp_image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-0694dfee3611> in <module>()
#       1 #matplotlib의 imread 명령어를 이용해 표준 형식(JPG,BMP,TIF)의 컬러 이미지 파일을 불러온다.
#       2 import tensorflow as tf
# ----> 3 import matplotlib.image as mp_image
#
# ImportError: No module named matplotlib.image

# %%
mport matplotlib.image as mp_image
# Out:
#   File "<ipython-input-3-ba6686aa0a3f>", line 1
#     mport matplotlib.image as mp_image
#                    ^
# SyntaxError: invalid syntax

# %%
import matplotlib.image as mp_image

# %%
filename ="example_1.jpg"

# %%
input_image =mp_image.imread(filename)

# %%
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-22-36b68b096635> in <module>()
# ----> 1 input_image =mp_image.imread('yeonho/example_1.jpg')
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/image.pyc in imread(fname, format)
#    1276
#    1277     if ext not in handlers:
# -> 1278         im = pilread(fname)
#    1279         if im is None:
#    1280             raise ValueError('Only know how to handle extensions: %s; '
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/image.pyc in pilread(fname)
#    1254         except ImportError:
#    1255             return None
# -> 1256         with Image.open(fname) as image:
#    1257             return pil_to_array(image)
#    1258
#
# /usr/local/lib/python2.7/dist-packages/PIL/Image.pyc in open(fp, mode)
#    2475
#    2476     if filename:
# -> 2477         fp = builtins.open(filename, "rb")
# ...

# %%
#불러온 텐서의 rnak와 shape를 확인해보자
print 'input dim={}'.format(input_image.ndim)
# Out:
# input dim=3

# %%
#%matplotlib를 이용해 불러온 이미지를 확인 해보자
import matplotlib.pyplot as plt

# %%
plt.imshow(input_image)
plt.show()

# %%
#자르기 연산자는 원본 이미지의 모든 RGB 평면에 적용돼야 한다. 따라서 plcaehoder를 이용해 잘라진 이미지를 저장 할 수 있는 변수를 생성한다.
import tensorflow as tf
my_image = tf.placeholder("uint8",[None,None,3])
